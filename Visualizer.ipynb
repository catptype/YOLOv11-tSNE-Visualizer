# %%
# %reset -f
from util.DirectoryProcessor import DirectoryProcessor
from util.Yolo11Visualizer import Yolo11Visualizer

PERPLEXITY = 100
COLORMAP = "hsv"

# Load image path
image_path = DirectoryProcessor.get_all_files(r"docs\images", True)

# Load model
visualizer = Yolo11Visualizer(r"models\yolov11s-cls_province_v2.pt")

# Calculate TSNE
visualizer.calculate_tsne(image_path, perplexity=PERPLEXITY, logit=True, worker=8)
# Out:
# 132/132 [████████████████████████████████████████] 100% | ETA: 0s	COMPLETE
# call property 'cls_pts' to retrieve class points

# %%
# Plot result (Full version)
visualizer.plot_tsne(colormap_name=COLORMAP, title=f"t-SNE Perplexity={PERPLEXITY}", export=True)

# %%
# Plot result (Compare version)
visualizer.plot_compare_tsne(colormap_name=COLORMAP, num_classes=2, export=False)
